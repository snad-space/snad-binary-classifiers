# %%
import pandas as pd
import numpy as np

# %%
table.columns
# Out:
# Index(['random seed', 'Accuracy score', 'Node id', 'Tree id', 'Node depth',
#        'Top-100 anomaly count'],
#       dtype='object')

# %%
table = pd.read_csv('../data/best_leaf_accuracy.csv')

print(f'average depth: {table['Node depth'].mean()} +- {table['Node depth'].std():.2f}')
print(f'average accuracy: {table['Accuracy score'].mean():.2f} +- {table['Accuracy score'].std():.2f}')
print(f'average Top-100 anomaly count: {table['Top-100 anomaly count'].mean():.2f} +- {table['Top-100 anomaly count'].std():.2f}')
# Out:
# average depth: 1.75 +- 0.97
# average accuracy: 0.09 +- 0.04
# average Top-100 anomaly count: 55.16 +- 11.66
