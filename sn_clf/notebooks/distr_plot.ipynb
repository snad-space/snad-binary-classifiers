# %%
import json
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt
import json
import time
import sys
sys.path.insert(0, '../..')

from sn_clf.scripts.utils import get_sn_label_from_akb, load_features, plot_config

plot_config()

# %%
oids, features = load_features('../../dr23-features/sid_snad_clf_r_100.dat', '../../dr23-features/feature_sn_hard.dat')

# %%
sn_score = np.array(features[:, -1])

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.hist(sn_score,
        bins=100,
        density=True,
        label='clear sample',
        color=u'#009ADE',
        log=True)
#ax.hist(sn_score_old, bins=100, density=True, label='noise sample',  alpha=0.5,  color='red')
plt.xlabel('SN score')
plt.ylabel('log(Density)')
plt.savefig('../figures/sn_score_all.pdf', dpi=400, format='pdf', bbox_inches="tight")

# %%
train = pd.read_csv('../data/train_data_big.csv')

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.hist(train['SN_clf_proba'],
        bins=100,
        density=True,
        label='clear sample',
        color=u'#009ADE',
        log=True)
#ax.hist(sn_score_old, bins=100, density=True, label='noise sample',  alpha=0.5,  color='red')
plt.xlabel('SN score')
plt.ylabel('log(Density)')
plt.savefig('../figures/sn_score_train.pdf', dpi=400, format='pdf', bbox_inches="tight")
